# %%
import pandas as pd

# %%
path1 = "Tabela5-sem_emprego_2012.csv"
path2 = "Tabela5-sem_emprego_2026.csv"
path3 = "Tabela 1.1.1.xls"

# %%
Tabela_regiao = pd.read_excel(path3,header=None)

# %%
Sem_emprego_2012= pd.read_csv(path1, sep=";", skiprows=0, decimal=",", encoding="UTF-8")

# %%
Sem_emprego_2026= pd.read_csv(path2, sep=";", skiprows=0, decimal=",", encoding="UTF-8")

# %%
Sem_emprego_2026 = Sem_emprego_2026.dropna(axis=1,how="all")
Sem_emprego_2012 = Sem_emprego_2012.dropna(axis=1,how="all")

# %% [markdown]
# # Teste tabela 2012

# %%
Sem_emprego_2012
# Out:
#    Sigla  Código               Estado  Desocupados - homens (2012 T1)  \
# 0     AC      12                 Acre                            45.3
# 1     AL      27              Alagoas                            44.7
# 2     AM      13             Amazonas                            47.5
# 3     AP      16                Amapá                            48.1
# 4     BA      29                Bahia                            43.8
# 5     CE      23                Ceará                            51.1
# 6     DF      53     Distrito Federal                            41.0
# 7     ES      32       Espírito Santo                            46.4
# 8     GO      52                Goiás                            41.0
# 9     MA      21             Maranhão                            47.2
# 10    MG      31         Minas Gerais                            43.1
# 11    MS      50   Mato Grosso do Sul                            47.2
# ...

# %% [markdown]
# # Teste tabela 2026

# %%
Sem_emprego_2026
# Out:
#    Sigla  Código               Estado  Desocupados - homens (2026 T1)  \
# 0     AC      12                 Acre                            53.2
# 1     AL      27              Alagoas                            50.7
# 2     AM      13             Amazonas                            46.8
# 3     AP      16                Amapá                            51.1
# 4     BA      29                Bahia                            44.7
# 5     CE      23                Ceará                            52.7
# 6     DF      53     Distrito Federal                            47.9
# 7     ES      32       Espírito Santo                            47.5
# 8     GO      52                Goiás                            47.5
# 9     MA      21             Maranhão                            49.1
# 10    MG      31         Minas Gerais                            48.6
# 11    MS      50   Mato Grosso do Sul                            45.3
# ...

# %% [markdown]
# # Juntar tabela

# %%
JuncaoAnoscomp = Sem_emprego_2012.merge(Sem_emprego_2026, on=["Sigla", "Código", "Estado"], how="inner")

# %% [markdown]
# # Teste junção das Tabelas

# %%
JuncaoAnoscomp
# Out:
#    Sigla  Código               Estado  Desocupados - homens (2012 T1)  \
# 0     AC      12                 Acre                            45.3
# 1     AL      27              Alagoas                            44.7
# 2     AM      13             Amazonas                            47.5
# 3     AP      16                Amapá                            48.1
# 4     BA      29                Bahia                            43.8
# 5     CE      23                Ceará                            51.1
# 6     DF      53     Distrito Federal                            41.0
# 7     ES      32       Espírito Santo                            46.4
# 8     GO      52                Goiás                            41.0
# 9     MA      21             Maranhão                            47.2
# 10    MG      31         Minas Gerais                            43.1
# 11    MS      50   Mato Grosso do Sul                            47.2
# ...
